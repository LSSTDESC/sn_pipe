# %%
import pandas as pd
from astroquery.gaia import Gaia

# %%
# Some functions
def chunks(lst, n):
    ""
    "Split an input list into multiple chunks of size =< n"
    ""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def get_spectra(source_id_list):
    dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
    #ids          = results_to_extract['source_id']
    ids = source_id_list
    ids_chunks   = list(chunks(ids, dl_threshold))
    datalink_all = []

    print(f'* Input list contains {len(ids)} source_IDs')
    print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')

    retrieval_type = 'XP_SAMPLED'        # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS' 
    data_structure = 'INDIVIDUAL'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW' - but as explained above, we strongly recommend to use COMBINED for massive downloads.
    data_release   = 'Gaia DR3'   # Options are: 'Gaia DR3' (default), 'Gaia DR2'
    dl_key         = f'{retrieval_type}_{data_structure}.csv'


    ii = 0
    for chunk in ids_chunks:
        ii = ii + 1
        print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
        datalink = Gaia.load_data(ids=chunk, 
                                  data_release = data_release, 
                                  retrieval_type=retrieval_type, 
                                  data_structure = data_structure, 
                                  verbose = True, 
                                  dump_to_file=True,
                                  overwrite_output_file=True,
                                  format="csv")
    
        datalink_all.append(datalink)

# %%
Gaia.login()
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# User:  pgris
# Password:  ········
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]

# %%
# load data
dataDir = '/home/philippe/LSST/sky_map_holo_F_stars'
dbName = 'baseline_v4.3.1_10yrs'
fName = '{}/{}/targets.hdf5'.format(dataDir,dbName)
results_to_extract= pd.read_hdf(fName)
print(results_to_extract)
# Out:
#        field            source_id sp_type_orig    ra_field  dec_field  \
# 0     COSMOS  3827549651604112256          F6V  146.449277  -1.913989
# 1     COSMOS  3827549651604112256          F6V  146.449277  -1.913989
# 2     COSMOS  3827549651604112256          F6V  146.449277  -1.913989
# 3     COSMOS  3827965056545783424       F8/G0V  146.770664  -0.619422
# 4     COSMOS  3827965056545783424       F8/G0V  146.770664  -0.619422
# ..       ...                  ...          ...         ...        ...
# 144  XMM_LSS  2486706972561857792          F5V   36.039486  -7.405703
# 145  XMM_LSS  2486706972561857792          F5V   36.039486  -7.405703
# 146  XMM_LSS  2486706972561857792          F5V   36.039486  -7.405703
# 147  XMM_LSS  2486706972561857792          F5V   36.039486  -7.405703
# 148  XMM_LSS  2486706972561857792          F5V   36.039486  -7.405703
#
#      dist_field[deg]   parallax  parallax_error  g_mag  phot_bp_mean_mag  ...  \
# 0           3.424259  11.506413        0.029334  7.968          8.209531  ...
# 1           3.424259  11.506413        0.029334  7.968          8.209531  ...
# 2           3.424259  11.506413        0.029334  7.968          8.209531  ...
# 3           2.305932  15.055609        0.027038  7.750          8.023091  ...
# 4           2.305932  15.055609        0.027038  7.750          8.023091  ...
# ..               ...        ...             ...    ...               ...  ...
# 144         0.783612  14.652494        0.032157  7.952          8.186659  ...
# 145         0.783612  14.652494        0.032157  7.952          8.186659  ...
# 146         0.783612  14.652494        0.032157  7.952          8.186659  ...
# 147         0.783612  14.652494        0.032157  7.952          8.186659  ...
# 148         0.783612  14.652494        0.032157  7.952          8.186659  ...
#
#          ra_deg   dec_deg    flux_max flux_max_type   ra_target  dec_target  \
# 0     36.926792 -1.907504   14.693833             G  146.449277   -1.913989
# 1     36.502332 -1.884432   19.377899             z  146.449277   -1.913989
# 2     37.502513 -1.922151   10.506000             K  146.449277   -1.913989
# 3     40.919181 -0.556850   14.386000             K  146.770664   -0.619422
# 4     41.162099 -0.652230   14.834000             K  146.770664   -0.619422
# ..          ...       ...         ...           ...         ...         ...
# 144  181.384572 -7.404871   18.555000             z   36.039486   -7.405703
# 145  181.108470 -7.393601   16.862000             z   36.039486   -7.405703
# 146  180.209667 -7.374417   10.989000             K   36.039486   -7.405703
# 147  179.931150 -7.357410  999.000000         999.0   36.039486   -7.405703
# 148  180.473708 -7.447683   19.465599             r   36.039486   -7.405703
#
#      dist[arcmin]       dra      ddec  dist_star[arcmin]
# 0        0.845040  0.012350  0.006111           0.826781
# 1        2.010313 -0.015931  0.029183           1.994910
# 2        3.090769  0.050710 -0.008535           3.085420
# 3        4.545722 -0.042487  0.062043           4.511739
# 4        2.531270 -0.026293 -0.033337           2.547494
# ..            ...       ...       ...                ...
# 144      3.143088  0.052343  0.000731           3.140915
# 145      2.172440  0.034090  0.012001           2.168459
# 146      2.413966 -0.025330  0.031185           2.410576
# 147      3.908129 -0.043743  0.048192           3.905045
# 148      2.562350 -0.007874 -0.042081           2.568682
#
# [149 rows x 43 columns]

# %%
llist = results_to_extract['source_id'].to_list()

for ch in list(chunks(llist,50)):
    get_spectra(ch)
# Out:
# * Input list contains 50 source_IDs
# * This list is split into 1 chunks of <= 5000 elements each
# Downloading Chunk #1; N_files = 50
# INFO: DataLink products will be stored in the /home/philippe/LSST/sn_pipe/notebooks/datalink_output_20251215T133614.695039.zip file [astroquery.gaia.core]
# Retrieving data.
# Data request: VALID_DATA=false&ID=3827549651604112256%2C3827549651604112256%2C3827549651604112256%2C3827965056545783424%2C3827965056545783424%2C3827965056545783424%2C3827965056545783424%2C3827965056545783424%2C3827965056545783424%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3830984079252585600%2C3836824650659925120%2C3836824650659925120%2C3836824650659925120%2C3836824650659925120%2C3836824650659925120%2C3848808605847847936%2C3848808605847847936%2C3848808605847847936%2C3848808605847847936%2C3848808605847847936%2C3850272261982861184%2C3850272261982861184%2C3850272261982861184%2C3850272261982861184%2C3850272261982861184%2C3850272261982861184%2C3850272261982861184%2C3856647883235816832%2C3856647883235816832%2C3856647883235816832%2C3856647883235816832%2C3856647883235816832%2C3856647883235816832%2C3856647883235816832&RELEASE=Gaia+DR3&DATA_STRUCTURE=INDIVIDUAL&FORMAT=csv&RETRIEVAL_TYPE=XP_SAMPLED&USE_ZIP_ALWAYS=true
# ------>https
# host = gea.esac.esa.int:443
# context = /data-server/data
# Content-type = application/x-www-form-urlencoded
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[38], line 4
#       1 llist = results_to_extract['source_id'].to_list()
#       3 for ch in list(chunks(llist,50)):
# ----> 4     get_spectra(ch)
#
# Cell In[34], line 21, in get_spectra(source_id_list)
#      19 ii = ii + 1
#      20 print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
# ---> 21 datalink = Gaia.load_data(ids=chunk,
#      22                           data_release = data_release,
#      23                           retrieval_type=retrieval_type,
#      24                           data_structure = data_structure,
#      25                           verbose = True,
#      26                           dump_to_file=True,
#      27                           overwrite_output_file=True,
#      28                           format="csv")
#      30 datalink_all.append(datalink)
#
# File ~/anaconda3/lib/python3.13/site-packages/astropy/utils/decorators.py:617, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     614             msg += f"\n        Use {alternative} instead."
#     615         warnings.warn(msg, warning_type, stacklevel=2)
# --> 617 return function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/astroquery/gaia/core.py:317, in GaiaClass.load_data(self, ids, data_release, data_structure, retrieval_type, linking_parameter, valid_data, band, avoid_datatype_check, format, dump_to_file, overwrite_output_file, verbose, output_file)
#     315     files = Gaia.__get_data_files(output_file=output_file, path=path)
#     316 except Exception as err:
# --> 317     raise err
#     318 finally:
#     319     if not output_file_specified:
#
# File ~/anaconda3/lib/python3.13/site-packages/astroquery/gaia/core.py:314, in GaiaClass.load_data(self, ids, data_release, data_structure, retrieval_type, linking_parameter, valid_data, band, avoid_datatype_check, format, dump_to_file, overwrite_output_file, verbose, output_file)
#     312 files = dict()
#     313 try:
# --> 314     self.__gaiadata.load_data(params_dict=params_dict, output_file=output_file, verbose=verbose)
#     315     files = Gaia.__get_data_files(output_file=output_file, path=path)
#     316 except Exception as err:
#
# File ~/anaconda3/lib/python3.13/site-packages/astroquery/utils/tap/core.py:869, in TapPlus.load_data(self, params_dict, output_file, verbose)
#     867 if verbose:
#     868     print(f"Data request: {data}")
# --> 869 response = connHandler.execute_datapost(data=data, verbose=verbose)
#     870 if verbose:
#     871     print(response.status, response.reason)
#
# File ~/anaconda3/lib/python3.13/site-packages/astroquery/utils/tap/conn/tapconn.py:292, in TapConn.execute_datapost(self, data, content_type, verbose)
#     274 """Executes a POST request
#     275 The connection is done through HTTP or HTTPS depending on the login
#     276 status (logged in -> HTTPS)
#    (...)
#     289 An HTTP(s) response object
#     290 """
#     291 context = self.__get_data_context()
# --> 292 return self.__execute_post(context, data, content_type, verbose=verbose)
#
# File ~/anaconda3/lib/python3.13/site-packages/astroquery/utils/tap/conn/tapconn.py:423, in TapConn.__execute_post(self, context, data, content_type, verbose)
#     421 self.__postHeaders["Content-type"] = content_type
#     422 conn.request("POST", context, data, self.__postHeaders)
# --> 423 response = conn.getresponse()
#     424 self.__currentReason = response.reason
#     425 self.__currentStatus = response.status
#
# File ~/anaconda3/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/anaconda3/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# ConnectionResetError: [Errno 104] Connection reset by peer
