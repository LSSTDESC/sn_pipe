# %%
import pandas as pd
from astroquery.gaia import Gaia
# Out:
# Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive

# %%
# Some functions
def chunks(lst, n):
    ""
    "Split an input list into multiple chunks of size =< n"
    ""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def get_spectra(source_id_list):
    dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
    #ids          = results_to_extract['source_id']
    ids = source_id_list
    ids_chunks   = list(chunks(ids, dl_threshold))
    datalink_all = []

    print(f'* Input list contains {len(ids)} source_IDs')
    print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')

    retrieval_type = 'XP_SAMPLED'        # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS' 
    data_structure = 'INDIVIDUAL'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW' - but as explained above, we strongly recommend to use COMBINED for massive downloads.
    data_release   = 'Gaia DR3'   # Options are: 'Gaia DR3' (default), 'Gaia DR2'
    dl_key         = f'{retrieval_type}_{data_structure}.csv'


    ii = 0
    for chunk in ids_chunks:
        ii = ii + 1
        print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
        datalink = Gaia.load_data(ids=chunk, 
                                  data_release = data_release, 
                                  retrieval_type=retrieval_type, 
                                  data_structure = data_structure, 
                                  verbose = True, 
                                  dump_to_file=True,
                                  overwrite_output_file=True,
                                  format="csv")
    
        datalink_all.append(datalink)

# %%
Gaia.login()
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# User:  pgris
# Password:  ········
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]

# %%
# load data
dataDir = '/home/philippe/LSST/holo_survey'
dbName = 'baseline_v4.3.1_10yrs'
fName = '{}/{}/targets.hdf5'.format(dataDir,dbName)
results_to_extract= pd.read_hdf(fName)
print(results_to_extract)
# Out:
#       field            source_id sp_type_orig  dist_field[deg]   parallax  \
# 0    COSMOS  3822906517079376000          A4V         4.851418  15.104043
# 1    COSMOS  3823289525082974464          B9V         4.394323   4.853174
# 3     ECDFS  4886526340114562432       A1V(n)         3.511822   5.870674
# 4     ECDFS  4887069052181688192          A1V         3.400524   9.417626
# 6     ECDFS  5061926069975057408          A1V         1.242562   9.007440
# ..      ...                  ...          ...              ...        ...
# 18   EDFS_b  4846714054864670848          F5V         4.419558  11.008127
# 19   EDFS_b  4848147543149497216          F3V         4.042689  11.871234
# 20  ELAISS1  4932651505735298560          F7V         4.238604  11.878257
# 21  ELAISS1  4987736999629756800          F9V         4.924318  29.755384
# 22  XMM_LSS  2486706972561857792          F5V         0.783612  14.652494
#
#     parallax_error     g_mag  phot_bp_mean_mag  phot_rp_mean_mag    ra_field  \
# 0         0.039774  5.995000          6.059958          5.851499  147.808521
# 1         0.034989  7.385000          7.368556          7.379488  148.427693
# 3         0.021615  7.930000          7.961572          7.842741   59.119680
# 4         0.070224  5.919000          5.923140          5.878578   60.169650
# 6         0.031227  6.354001          6.347639          6.338865   50.567885
# ..             ...       ...               ...               ...         ...
# 18        0.024958  7.918001          8.147873          7.523345   53.072900
# 19        0.020593  7.733000          7.925478          7.387986   53.704431
# 20        0.017220  7.823000          8.048443          7.436820   13.599169
# 21        0.015962  6.880000          7.154478          6.437614   16.884713
# 22        0.032157  7.952000          8.186659          7.555875   36.039486
#
#     ...      ra_deg    dec_deg   flux_max flux_max_type   ra_target  \
# 0   ...   56.708857  -4.186673       8.39             K  147.808521
# 1   ...   66.458125  -3.878528  16.243999             R  148.427693
# 3   ...   167.13125 -31.641667      999.0         999.0    59.11968
# 4   ...  183.018335 -30.508952  19.783581             G    60.16965
# 6   ...   37.941016 -25.613238      8.064             K   50.567885
# ..  ...         ...        ...        ...           ...         ...
# 18  ...   75.895746 -44.428458  20.279503             G     53.0729
# 19  ...    85.69375 -44.620278      999.0         999.0   53.704431
# 20  ...   203.94375 -48.937639      999.0         999.0   13.599169
# 21  ...  253.174937 -41.753061      999.0         999.0   16.884713
# 22  ...   181.10847  -7.393601     16.862             z   36.039486
#
#    dec_target dist[arcmin]       dra      ddec dist_star[arcmin]
# 0    -4.24347     3.795537 -0.027799  0.056677          3.787612
# 1   -3.861998     1.006341  0.002783  -0.01652          1.005135
# 3  -31.695418     3.421875  0.019091  0.053779          3.424048
# 4  -30.490684     1.966217   0.02742 -0.018243          1.976057
# 6  -25.587805     2.581801 -0.034686 -0.025433          2.580666
# ..        ...          ...       ...       ...               ...
# 18 -44.409073     1.293077 -0.009614 -0.019351          1.296426
# 19 -44.643334     1.430016  0.005987  0.023091            1.4313
# 20 -48.948575     0.666172 -0.001736  0.010731          0.652212
# 21 -41.746983     0.463319 -0.003894  -0.00636          0.447456
# 22  -7.405703      2.17244   0.03409  0.012001          2.168459
#
# [65 rows x 43 columns]

# %%
llist = results_to_extract['source_id'].unique()
print(llist)
for ch in chunks(llist,10):
    get_spectra(ch)
# Out:
# [3822906517079376000 3823289525082974464 4886526340114562432
#  4887069052181688192 5061926069975057408 5071668533270215040
#  5073393185976634752 5073486644466270592 5080104261356834304
#  5081897633541187072 5083248005616972032 4683464272088609664
#  4683638922639072768 4779816503255644672 4782733438884513152
